# %%
import pandas as pd 
from w3lib.url import url_query_cleaner
from url_normalize import url_normalize
import re

# %%
data_in_excel = pd.read_excel('Sample.xlsx')

# %% [markdown]
# # 2

# %% [markdown]
# 2.	Clean the urls (refer the given excel sheet)
#
# Example:
#
# Raw url:  https://technology/gadgets/apple-iphone-12-review-an-iterative-update-over-iphone-11-11605525335131.html
#
#
# Cleaned url: technology/gadgets/apple-iphone-12-review-an-iterative-update-over-iphone-11
#
#
# Basically, we removed “https://” and “11605525335131.html”, similarly it should be done for all urls

# %%
data_in_excel.shape
# Out:
# (500, 10)

# %%
data_in_excel.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   urls             500 non-null    object
#  1   pageviews        500 non-null    int64
#  2   users            500 non-null    int64
#  3   new_users        500 non-null    int64
#  4   returning_users  500 non-null    int64
#  5   Unnamed: 5       0 non-null      float64
#  6   Unnamed: 6       0 non-null      float64
#  7   Unnamed: 7       0 non-null      float64
#  8   Unnamed: 8       0 non-null      float64
#  9   Unnamed: 9       0 non-null      float64
# dtypes: float64(5), int64(4), object(1)
# memory usage: 39.2+ KB

# %%
data_in_excel.head()
# Out:
#                                                 urls  pageviews  users  \
# 0  https://companies/news/it-sector-hiring-in-new...      16906  16137
# 1  https://market/commodities/gold-prices-today-f...       5052   4563
# 2  https://market/stock-market-news/wall-street-u...       2333   2170
# 3  https://news/india/now-only-50-people-allowed-...       1409   1307
# 4  https://news/india/fall-in-exports-surge-in-in...        954    887
#
#    new_users  returning_users  Unnamed: 5  Unnamed: 6  Unnamed: 7  Unnamed: 8  \
# 0       3509            12628         NaN         NaN         NaN         NaN
# 1       2090             2473         NaN         NaN         NaN         NaN
# 2         33             2137         NaN         NaN         NaN         NaN
# 3        424              883         NaN         NaN         NaN         NaN
# 4        111              776         NaN         NaN         NaN         NaN
#
#    Unnamed: 9
# 0         NaN
# 1         NaN
# 2         NaN
# ...

# %%
data_in_excel.columns
# Out:
# Index(['urls', 'pageviews', 'users', 'new_users', 'returning_users',
#        'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9'],
#       dtype='object')

# %%
data_in_excel.drop(['Unnamed: 5','Unnamed: 6','Unnamed: 7','Unnamed: 8','Unnamed: 9' ], axis=1, inplace=True)

# %%
data_in_excel['clean_url'] =data_in_excel['urls'].values

# %%
data_in_excel['clean_url']
# Out:
# 0      https://companies/news/it-sector-hiring-in-new...
# 1      https://market/commodities/gold-prices-today-f...
# 2      https://market/stock-market-news/wall-street-u...
# 3      https://news/india/now-only-50-people-allowed-...
# 4      https://news/india/fall-in-exports-surge-in-in...
#                              ...
# 495    https://news/india/coronavirus-lockdown-4-0-al...
# 496    https://news/india/covid-19-pm-modi-reviews-si...
# 497    https://news/india/delhi-hc-allows-vedanta-to-...
# 498    https://news/india/drive-through-covid-19-test...
# 499    https://news/india/frauds-rise-as-india-s-econ...
# Name: clean_url, Length: 500, dtype: object

# %%
data_in_excel.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   urls             500 non-null    object
#  1   pageviews        500 non-null    int64
#  2   users            500 non-null    int64
#  3   new_users        500 non-null    int64
#  4   returning_users  500 non-null    int64
#  5   clean_url        500 non-null    object
# dtypes: int64(4), object(2)
# memory usage: 23.6+ KB

# %%
data_in_excel['clean_url']
# Out:
# 0      https://companies/news/it-sector-hiring-in-new...
# 1      https://market/commodities/gold-prices-today-f...
# 2      https://market/stock-market-news/wall-street-u...
# 3      https://news/india/now-only-50-people-allowed-...
# 4      https://news/india/fall-in-exports-surge-in-in...
#                              ...
# 495    https://news/india/coronavirus-lockdown-4-0-al...
# 496    https://news/india/covid-19-pm-modi-reviews-si...
# 497    https://news/india/delhi-hc-allows-vedanta-to-...
# 498    https://news/india/drive-through-covid-19-test...
# 499    https://news/india/frauds-rise-as-india-s-econ...
# Name: clean_url, Length: 500, dtype: object

# %%
data_in_excel['clean_url'].values
# Out:
# array(['https://companies/news/it-sector-hiring-in-new-age-skills-to-pick-up-in-2021/amp-11605686860932.html',
#        'https://market/commodities/gold-prices-today-fall-for-4th-day-in-row-silver-rates-slump-11605754985040.html',
#        'https://market/stock-market-news/wall-street-us-stocks-decline-as-covid-19-cases-surge-jobless-claims-rise-11605801157893.html',
#        'https://news/india/now-only-50-people-allowed-at-weddings-in-delhi-to-check-covid-19-surge/amp-11605687140134.html',
#        'https://news/india/fall-in-exports-surge-in-inflation-puts-india-behind-em-peers/amp-11605684204641.html',
#        'https://Epaper/M/Delhi/19/11/2020/Page/01',
#        'https://technology/gadgets/apple-iphone-12-review-an-iterative-update-over-iphone-11-11605525335131.html',
#        'https://market/market-stats/',
#        'https://companies/news/tata-group-to-set-up-rs-5000-crore-phone-component-making-unit-in-tn-report-11603867877879.html',
# ...

# %%
from w3lib.url import url_query_cleaner
from url_normalize import url_normalize

urls = ['example.com',
'example.com/',
'http://example.com///',
'http://example.com',
'http://example.com?',
'http://example.com/?',
'http://example.com//',
'market/stock-market-news/wall-street-us-stocks-decline-as-covid-19-cases-surge-jobless-claims-rise-11605801157893.html',
'http://example.com?utm_source=Google']

sss= 'market/stock-market-news/wall-street-us-stocks-decline-as-covid-19-cases-surge-jobless-claims-rise-11605801157893.html'

# sss=  'http://example.com//'

reg = '\-[\d]{14}\.html'

for i in urls:
    match_pattern = re.findall(reg,i)
    
    if match_pattern:
        print('Yes')

    else:
        print('NO')
    
    
print(t)

def canonical_url(u):
    
    u = url_normalize(u)
    u = url_query_cleaner(u,parameterlist = ['utm_source','utm_medium','utm_campaign','utm_term','utm_content'],remove=True)  
    
    match_pattern = re.findall(reg,u)
    if match_pattern:
        if u.endswith('html'):
            u = u[:-20]
    else:    
        if u.startswith("http://"):
            u = u[7:]
        if u.startswith("https://"):
            u = u[8:]
        if u.startswith("www."):
            u = u[4:]
        if u.endswith("/"):
            u = u[:-1]
    
    return u

t = list(map(canonical_url,data_in_excel['clean_url'].values))
# Out:
# NO
# NO
# NO
# NO
# NO
# NO
# NO
# Yes
# NO
# ...

# %%
data_in_excel['clean_url'] = t

# %%
data_in_excel
# Out:
#                                                   urls  pageviews  users  \
# 0    https://companies/news/it-sector-hiring-in-new...      16906  16137
# 1    https://market/commodities/gold-prices-today-f...       5052   4563
# 2    https://market/stock-market-news/wall-street-u...       2333   2170
# 3    https://news/india/now-only-50-people-allowed-...       1409   1307
# 4    https://news/india/fall-in-exports-surge-in-in...        954    887
# ..                                                 ...        ...    ...
# 495  https://news/india/coronavirus-lockdown-4-0-al...          3      3
# 496  https://news/india/covid-19-pm-modi-reviews-si...          3      3
# 497  https://news/india/delhi-hc-allows-vedanta-to-...          3      2
# 498  https://news/india/drive-through-covid-19-test...          3      3
# 499  https://news/india/frauds-rise-as-india-s-econ...          3      3
#
#      new_users  returning_users  \
# 0         3509            12628
# ...

# %%
clean_url = data_in_excel.to_csv('cleaned_url_with_sample_data.csv')

# %% [markdown]
# # 3

# %% [markdown]
# 3.	Make a new dataframe which contains
#
# #### only those rows which have the
#
# # number of returning_users  > new_users
#
# (refer excel sheet)

# %%
data_in_excel
# Out:
#                                                   urls  pageviews  users  \
# 0    https://companies/news/it-sector-hiring-in-new...      16906  16137
# 1    https://market/commodities/gold-prices-today-f...       5052   4563
# 2    https://market/stock-market-news/wall-street-u...       2333   2170
# 3    https://news/india/now-only-50-people-allowed-...       1409   1307
# 4    https://news/india/fall-in-exports-surge-in-in...        954    887
# ..                                                 ...        ...    ...
# 495  https://news/india/coronavirus-lockdown-4-0-al...          3      3
# 496  https://news/india/covid-19-pm-modi-reviews-si...          3      3
# 497  https://news/india/delhi-hc-allows-vedanta-to-...          3      2
# 498  https://news/india/drive-through-covid-19-test...          3      3
# 499  https://news/india/frauds-rise-as-india-s-econ...          3      3
#
#      new_users  returning_users  \
# 0         3509            12628
# ...

# %%
data_in_excel[data_in_excel['returning_users'] > data_in_excel['new_users']]
# Out:
#                                                   urls  pageviews  users  \
# 0    https://companies/news/it-sector-hiring-in-new...      16906  16137
# 1    https://market/commodities/gold-prices-today-f...       5052   4563
# 2    https://market/stock-market-news/wall-street-u...       2333   2170
# 3    https://news/india/now-only-50-people-allowed-...       1409   1307
# 4    https://news/india/fall-in-exports-surge-in-in...        954    887
# ..                                                 ...        ...    ...
# 492  https://news/india/air-india-express-flight-wi...          3      3
# 493  https://news/india/babri-masjid-demolition-cas...          3      2
# 494  https://news/india/centre-raises-excise-duty-o...          3      2
# 496  https://news/india/covid-19-pm-modi-reviews-si...          3      3
# 499  https://news/india/frauds-rise-as-india-s-econ...          3      3
#
#      new_users  returning_users  \
# 0         3509            12628
# ...

# %%
number_of_returning_user_grater_then_new_users= data_in_excel[data_in_excel['returning_users'] > data_in_excel['new_users']].to_csv('dataset_contain_returning_user_grater_than_new_user.csv')
