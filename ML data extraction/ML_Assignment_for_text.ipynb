# %% [markdown]
# pip install tabulate

# %% [markdown]
# pip install tabula-py

# %%
from tabula import read_pdf
from tabulate import tabulate

# %%
df = read_pdf("Assignment.pdf", pages='all', multiple_tables=True)
print(tabulate(df))
# Out:
# Got stderr: Aug 25, 2021 11:47:12 AM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# WARNING: No Unicode mapping for .notdef (9) in font Times-Roman
# Aug 25, 2021 11:47:13 AM org.apache.pdfbox.rendering.Type1Glyph2D getPathForCharacterCode
# WARNING: No glyph for code 9 (.notdef) in font Times-Roman
# ...

# %%
df = read_pdf("Assignment.pdf")
df
# Out:
# 'pages' argument isn't specified.Will extract only from page 1 by default.
# [     Tran Date  Chq No                                 Particulars     Debit  \
#  0          NaN     NaN                                         NaN       NaN
#  1          NaN     NaN                             OPENING BALANCE       NaN
#  2          NaN     NaN                            BY CASH DEPOSIT-       NaN
#  3   18-01-2020     NaN            BNA/APRH38403/802/180120/BORIVAL       NaN
#  4          NaN     NaN                                         NaN       NaN
#  5   18-01-2020     NaN        NEFT/MB/AXMB200183005469/munna kumar  40000.00
#  6   18-01-2020     NaN                          GST @18% on Charge     56.70
#  7   18-01-2020     NaN                Consolidated Charges for A/c    315.00
#  8          NaN     NaN                            BY CASH DEPOSIT-       NaN
#  9   23-01-2020     NaN           BNA/APRH38403/2247/230120/BORIVAL       NaN
# ...

# %%
df = read_pdf("Assignment.pdf", encoding = 'ISO-8859-1',
         stream=True, area = [500, 25, 1080, 961])
df
# Out:
# 'pages' argument isn't specified.Will extract only from page 1 by default.
# [    24-01-2020          NEFT/MB/AXMB200244852844/kamruddin  20000.00  \
#  0          NaN                                         NaN       NaN
#  1   24-01-2020             NEFT/MB/AXMB200245017824/gaurav   4000.00
#  2          NaN                            BY CASH DEPOSIT-       NaN
#  3   27-01-2020           BNA/APRH38403/3316/270120/BORIVAL       NaN
#  4          NaN                            BY CASH DEPOSIT-       NaN
#  5   27-01-2020           BNA/APRH38403/3318/270120/BORIVAL       NaN
#  6          NaN    IMPS/P2A/002716754721/kaledh/BANKOFI/X00       NaN
#  7   27-01-2020                                       1755/      3.95
#  8          NaN                                         NaN       NaN
#  9   27-01-2020           NEFT/MB/AXMB200275464751/kaledhon  70000.00
#  10         NaN        AXMOB/MBR/XP6SU0SY4637/9180200976168       NaN
# ...
