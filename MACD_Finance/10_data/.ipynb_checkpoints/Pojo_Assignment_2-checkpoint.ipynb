# %% [markdown]
# # Import library

# %%
from pynse import *
import datetime
import logging
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from itertools import islice
import datetime
from dateutil.relativedelta import relativedelta

# config logging

logging.basicConfig(level=logging.DEBUG)

# %%
Selec_No_of_years_to_show_data= 1

# %%
nse = Nse()
# Out:
# INFO:pynse.core:pyNse cache size: (6.07, 'MB').
# You may want to run `nse.clear_data()` if running low on disk space.

# %% [markdown]
# ### Return Market status

# %%
nse.market_status()
# Out:
# INFO:pynse.core:downloading market status
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.nseindia.com:443
# DEBUG:urllib3.connectionpool:https://www.nseindia.com:443 "GET / HTTP/1.1" 200 40824
# DEBUG:urllib3.connectionpool:https://www.nseindia.com:443 "GET /api/marketStatus HTTP/1.1" 200 227
# {'marketState': [{'market': 'Capital Market',
#    'marketStatus': 'Open',
#    'tradeDate': '06-Sep-2021',
#    'index': 'NIFTY 50',
#    'last': 17364.25,
#    'variation': 40.650000000001455,
#    'percentChange': 0.23,
#    'marketStatusMessage': 'Normal Market is Open'},
#   {'market': 'Currency',
#    'marketStatus': 'Open',
#    'tradeDate': '06-Sep-2021',
#    'index': '',
#    'last': '',
#    'variation': '',
#    'percentChange': '',
#    'marketStatusMessage': 'Market is Open'},
#   {'market': 'Commodity',
#    'marketStatus': 'Open',
#    'tradeDate': '06-Sep-2021',
#    'index': '',
#    'last': '',
#    'variation': '',
#    'percentChange': '',
#    'marketStatusMessage': 'Market is Open'},
#   {'market': 'Debt',
#    'marketStatus': 'Open',
#    'tradeDate': '06-Sep-2021',
#    'index': '',
#    'last': '',
#    'variation': '',
#    'percentChange': '',
#    'marketStatusMessage': 'Market is Open'}]}

# %% [markdown]
# Bhavcopy
#
# The Bhav Copy is a snapshot of the activity that has taken place in the market for the particular day. ...
# You can use it to observe activity taking place in any particular scrip or across the broad market,
# as it contains End Of Day (EOD) details of the entire market.

# %%
nse.bhavcopy()
# Out:
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.nseindia.com:443
# DEBUG:urllib3.connectionpool:https://www.nseindia.com:443 "GET / HTTP/1.1" 200 40876
# DEBUG:urllib3.connectionpool:https://www.nseindia.com:443 "GET /api/historical/cm/equity?symbol=SBIN&series=%5B%22EQ%22%5D&from=27-08-2021&to=06-09-2021&csv=true HTTP/1.1" 200 437
# DEBUG:pynse.core:read C:\Users\kumar\.pynse/bhavcopy_eq/bhav_2021-09-03.pkl from disk
#                         DATE1  PREV_CLOSE  OPEN_PRICE  HIGH_PRICE  LOW_PRICE  \
# SYMBOL     SERIES
# 20MICRONS  EQ      2021-09-03       53.85       54.45       54.85      53.15
# 21STCENMGM EQ      2021-09-03       34.85       35.50       35.50      35.50
# 3MINDIA    EQ      2021-09-03    24543.05    24900.00    25000.00   24400.00
# 5PAISA     EQ      2021-09-03      466.15      463.00      475.10     463.00
# 63MOONS    EQ      2021-09-03       94.80       93.75       99.45      93.75
# ...                       ...         ...         ...         ...        ...
# ZODIACLOTH EQ      2021-09-03      113.05      115.70      118.90     112.20
# ZODJRDMKJ  EQ      2021-09-03       30.95       31.65       31.70      30.45
# ZOMATO     EQ      2021-09-03      137.60      135.95      151.40     135.60
# ZOTA       EQ      2021-09-03      381.85      386.75      388.75     371.55
# ZYDUSWELL  EQ      2021-09-03     2319.40     2320.00     2325.00    2287.15
#
#                    LAST_PRICE  CLOSE_PRICE  AVG_PRICE  TTL_TRD_QNTY  \
# SYMBOL     SERIES
# 20MICRONS  EQ           53.55        53.60      53.79         53659
# 21STCENMGM EQ           35.50        35.50      35.50           998
# 3MINDIA    EQ        24600.00     24537.05   24799.79          4348
# 5PAISA     EQ          471.45       471.30     471.19         17740
# 63MOONS    EQ           97.20        96.80      97.93        136393
# ...                       ...          ...        ...           ...
# ZODIACLOTH EQ          113.80       113.50     116.14        105715
# ZODJRDMKJ  EQ           31.50        31.35      31.07          8461
# ZOMATO     EQ          149.00       149.75     146.54     113381518
# ZOTA       EQ          377.00       378.20     379.30         53019
# ZYDUSWELL  EQ         2294.95      2301.05    2308.59         16645
#
#                    TURNOVER_LACS  NO_OF_TRADES DELIV_QTY DELIV_PER
# SYMBOL     SERIES
# 20MICRONS  EQ              28.86           647     33348     62.15
# 21STCENMGM EQ               0.35            13       998    100.00
# 3MINDIA    EQ            1078.29          1631      2632     60.53
# 5PAISA     EQ              83.59           512      6406     36.11
# 63MOONS    EQ             133.57          1926     75668     55.48
# ...                          ...           ...       ...       ...
# ZODIACLOTH EQ             122.78          2753     45302     42.85
# ZODJRDMKJ  EQ               2.63           264      1240     14.66
# ZOMATO     EQ          166147.44        487984  22627095     19.96
# ZOTA       EQ             201.10          1981     30949     58.37
# ZYDUSWELL  EQ             384.27          2694     10069     60.49
#
# [1519 rows x 13 columns]

# %% [markdown]
# Sort data by average price

# %%
daily_share_price =nse.bhavcopy()
filt = daily_share_price.sort_values(by= ['AVG_PRICE'],ascending=False).head(5)

filt
top_5_share_by_average_price= filt
top_5_share_by_average_price
# Out:
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.nseindia.com:443
# DEBUG:urllib3.connectionpool:https://www.nseindia.com:443 "GET / HTTP/1.1" 200 40784
# DEBUG:urllib3.connectionpool:https://www.nseindia.com:443 "GET /api/historical/cm/equity?symbol=SBIN&series=%5B%22EQ%22%5D&from=27-08-2021&to=06-09-2021&csv=true HTTP/1.1" 200 437
# DEBUG:pynse.core:read C:\Users\kumar\.pynse/bhavcopy_eq/bhav_2021-09-03.pkl from disk
#                       DATE1  PREV_CLOSE  OPEN_PRICE  HIGH_PRICE  LOW_PRICE  \
# SYMBOL   SERIES
# MRF      EQ      2021-09-03    81265.15     81949.0    82600.10   81509.90
# HONAUT   EQ      2021-09-03    40517.35     40599.9    40603.05   40084.05
# PAGEIND  EQ      2021-09-03    32049.55     32032.0    32949.85   32032.00
# SHREECEM EQ      2021-09-03    30323.25     30290.1    30590.80   29962.10
# 3MINDIA  EQ      2021-09-03    24543.05     24900.0    25000.00   24400.00
#
#                  LAST_PRICE  CLOSE_PRICE  AVG_PRICE  TTL_TRD_QNTY  \
# SYMBOL   SERIES
# MRF      EQ         82300.0     82397.85   82217.08         15764
# HONAUT   EQ         40175.0     40161.60   40445.65          3233
# PAGEIND  EQ         32386.6     32473.30   32493.84         18937
# SHREECEM EQ         30400.0     30440.80   30275.16         81600
# 3MINDIA  EQ         24600.0     24537.05   24799.79          4348
#
#                  TURNOVER_LACS  NO_OF_TRADES DELIV_QTY DELIV_PER
# SYMBOL   SERIES
# MRF      EQ           12960.70         10243      4431     28.11
# HONAUT   EQ            1307.61          1132      2187     67.65
# PAGEIND  EQ            6153.36          9938      6096     32.19
# SHREECEM EQ           24704.53         29680     20487     25.11
# 3MINDIA  EQ            1078.29          1631      2632     60.53

# %% [markdown]
# Here Symbol and series are index, to proced further, First reset indexes.

# %%
top_5_share_by_average_price.index
# Out:
# MultiIndex([(     'MRF', 'EQ'),
#             (  'HONAUT', 'EQ'),
#             ( 'PAGEIND', 'EQ'),
#             ('SHREECEM', 'EQ'),
#             ( '3MINDIA', 'EQ')],
#            names=['SYMBOL', 'SERIES'])

# %% [markdown]
# # Reset Index

# %%
top_5_share_by_average_price= top_5_share_by_average_price.reset_index()
top_5_share_by_average_price
# Out:
#      SYMBOL SERIES       DATE1  PREV_CLOSE  OPEN_PRICE  HIGH_PRICE  LOW_PRICE  \
# 0       MRF     EQ  2021-09-03    81265.15     81949.0    82600.10   81509.90
# 1    HONAUT     EQ  2021-09-03    40517.35     40599.9    40603.05   40084.05
# 2   PAGEIND     EQ  2021-09-03    32049.55     32032.0    32949.85   32032.00
# 3  SHREECEM     EQ  2021-09-03    30323.25     30290.1    30590.80   29962.10
# 4   3MINDIA     EQ  2021-09-03    24543.05     24900.0    25000.00   24400.00
#
#    LAST_PRICE  CLOSE_PRICE  AVG_PRICE  TTL_TRD_QNTY  TURNOVER_LACS  \
# 0     82300.0     82397.85   82217.08         15764       12960.70
# 1     40175.0     40161.60   40445.65          3233        1307.61
# 2     32386.6     32473.30   32493.84         18937        6153.36
# 3     30400.0     30440.80   30275.16         81600       24704.53
# 4     24600.0     24537.05   24799.79          4348        1078.29
#
#    NO_OF_TRADES DELIV_QTY DELIV_PER
# 0         10243      4431     28.11
# 1          1132      2187     67.65
# 2          9938      6096     32.19
# 3         29680     20487     25.11
# 4          1631      2632     60.53

# %% [markdown]
# ### Store top 5 share in list

# %%
list_of_top_5_share= []
list_of_top_5_share= top_5_share_by_average_price['SYMBOL']
print(list_of_top_5_share)
# Out:
# 0         MRF
# 1      HONAUT
# 2     PAGEIND
# 3    SHREECEM
# 4     3MINDIA
# Name: SYMBOL, dtype: object

# %% [markdown]
# Create pandas data_frame

# %%
pd_data_frame = pd.DataFrame(top_5_share_by_average_price)

# %% [markdown]
# # Set time duration to fetch data

# %%
datetime.date.today()
# Out:
# datetime.date(2021, 9, 6)

# %%
years_ago = datetime.date.today() - relativedelta(years=Selec_No_of_years_to_show_data)

years_ago
# Out:
# datetime.date(2020, 9, 6)

# %% [markdown]
# # Testing of getting data from NSE

# %%
hdfc= nse.get_hist('HDFC', years_ago,datetime.date.today())
hdfc
# Out:
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.nseindia.com:443
# DEBUG:urllib3.connectionpool:https://www.nseindia.com:443 "GET / HTTP/1.1" 200 40724
# DEBUG:urllib3.connectionpool:https://www.nseindia.com:443 "GET /api/historical/cm/equity?symbol=HDFC&series=%5B%22EQ%22%5D&from=06-09-2020&to=06-09-2021&csv=true HTTP/1.1" 200 11094
#                open     high      low    close   volume
# Date
# 2020-09-07  1773.00  1801.45  1760.00  1791.10  4073465
# 2020-09-08  1785.10  1793.25  1770.80  1777.30  2456321
# 2020-09-09  1759.55  1777.90  1755.00  1760.75  2509630
# 2020-09-10  1781.00  1792.95  1760.00  1777.45  3245630
# 2020-09-11  1771.00  1786.00  1760.00  1768.15  2232185
# ...             ...      ...      ...      ...      ...
# 2021-08-30  2730.45  2764.90  2723.10  2755.70  1731926
# 2021-08-31  2748.00  2812.00  2739.35  2798.50  4933523
# 2021-09-01  2790.00  2796.95  2736.60  2747.75  3084291
# 2021-09-02  2756.90  2785.00  2737.25  2777.70  1734037
# 2021-09-03  2768.10  2784.15  2742.10  2758.60  1914438
#
# [248 rows x 5 columns]

# %% [markdown]
#
#  # Objective is to pridict MACD , lowEMA, SIGNAL_EMA,and longEMA of TOP 5 Share by  Average Price

# %%
list_of_top_5_share
# Out:
# 0         MRF
# 1      HONAUT
# 2     PAGEIND
# 3    SHREECEM
# 4     3MINDIA
# Name: SYMBOL, dtype: object

# %%
list_of_data= []
for i in list_of_top_10_share:
    list_of_data.append(nse.get_hist(i, years_ago,datetime.date.today()))
list_of_data
# Out:
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.nseindia.com:443
# DEBUG:urllib3.connectionpool:https://www.nseindia.com:443 "GET / HTTP/1.1" 200 
#  2021-09-01  18802.0  18802.00  18200.00  18297.00    1036
#  2021-09-02  18490.0  19000.00  18171.00  18888.35    2887
#  2021-09-03  18800.0  18929.00  18625.25  18872.85    1061
#
#  [248 rows x 5 columns],
#                  open      high       low     close  volume
#  Date
#  2020-09-07   6324.00   6349.25   6212.00   6263.65  498573
#  2020-09-08   6299.00   6330.00   6212.05   6234.25  391769
#  2020-09-09   6208.80   6220.00   5981.60   6026.80  929750
#  2020-09-10   6079.00   6192.00   6042.85   6129.25  531609
#  2020-09-11   6128.55   6174.60   6080.00   6128.40  465485
#  ...              ...       ...       ...       ...     ...
#  2021-08-30  16475.00  16595.00  16260.00  16560.40  336038
#  2021-08-31  16500.00  17200.00  16428.25  17148.75  652127
#  2021-09-01  17166.45  17263.50  16740.15  16786.30  461843
#  2021-09-02  16865.00  16900.00  16610.00  16703.25  276879
#  2021-09-03  16776.80  16859.85  16560.00  16734.35  248555
#
#  [248 rows x 5 columns]]

# %%
list_of_data_frame_of_share_market[0]
# Out:
#                open      high       low     close  volume
# Date
# 2020-09-07  58425.4  58854.95  58000.00  58374.20   12609
# 2020-09-08  58500.0  58500.00  58050.00  58212.65    9805
# 2020-09-09  58200.0  59054.95  57867.00  58763.55   12863
# 2020-09-10  58865.0  59399.00  58700.00  59134.05    9822
# 2020-09-11  59100.0  59400.00  58445.90  59226.70   14081
# ...             ...       ...       ...       ...     ...
# 2021-08-30  77000.0  78374.95  77000.00  78185.50    9045
# 2021-08-31  78300.0  79855.05  78257.80  79742.75   14859
# 2021-09-01  80000.0  80559.95  79239.80  79954.65   10789
# 2021-09-02  80393.0  81875.55  80041.45  81265.15   14947
# 2021-09-03  81949.0  82600.10  81509.90  82397.85   15764
#
# [248 rows x 5 columns]

# %% [markdown]
# longEMA= df.Close.ewm(span=21, adjust=False).mean()
# longEMA

# %% [markdown]
# ## Calculate 3 moving averages according to closig market

# %%
list_of_data_frame_of_share_market[0]
# Out:
#                open      high       low     close  volume
# Date
# 2019-09-06  58080.0  58980.00  57900.10  58754.30    2892
# 2019-09-09  58802.0  59200.00  58333.00  58869.10    2887
# 2019-09-11  58950.0  60280.00  58875.05  60101.95    6205
# 2019-09-12  60256.0  61109.95  60000.00  60658.90    7908
# 2019-09-13  60754.0  60996.70  59760.05  60119.95    7070
# ...             ...       ...       ...       ...     ...
# 2021-08-30  77000.0  78374.95  77000.00  78185.50    9045
# 2021-08-31  78300.0  79855.05  78257.80  79742.75   14859
# 2021-09-01  80000.0  80559.95  79239.80  79954.65   10789
# 2021-09-02  80393.0  81875.55  80041.45  81265.15   14947
# 2021-09-03  81949.0  82600.10  81509.90  82397.85   15764
#
# [496 rows x 5 columns]

# %% [markdown]
# # Find values short Signam and Long 'MACD' Lines.

# %%
list_of_EMA =[]


# signalEMA= list_of_data_frame_of_share_market[0]['close'].ewm(span=12, adjust=False).mean()
# longEMA= list_of_data_frame_of_share_market[0]['close'].ewm(span=26, adjust=False).mean()

# for i in range(len(list_of_data_frame_of_share_market)):
#     print(len(list_of_data_frame_of_share_market))
#     print(type(i))
#     print(ord('i'))
#     j= ord('i')- 105

shortEMA= list_of_data_frame_of_share_market[0]['close'].ewm(span=9, adjust=False).mean()
signalEMA= list_of_data_frame_of_share_market[0]['close'].ewm(span=12, adjust=False).mean()
longEMA= list_of_data_frame_of_share_market[0]['close'].ewm(span=26, adjust=False).mean()
        
        
shortEMA_1= list_of_data_frame_of_share_market[1]['close'].ewm(span=9, adjust=False).mean()
signalEMA_1= list_of_data_frame_of_share_market[1]['close'].ewm(span=12, adjust=False).mean()
longEMA_1= list_of_data_frame_of_share_market[1]['close'].ewm(span=26, adjust=False).mean()
        
        
shortEMA_2= list_of_data_frame_of_share_market[2]['close'].ewm(span=9, adjust=False).mean()
signalEMA_2= list_of_data_frame_of_share_market[2]['close'].ewm(span=12, adjust=False).mean()
longEMA_2= list_of_data_frame_of_share_market[2]['close'].ewm(span=26, adjust=False).mean()
       
shortEMA_3= list_of_data_frame_of_share_market[3]['close'].ewm(span=9, adjust=False).mean()
signalEMA_3= list_of_data_frame_of_share_market[3]['close'].ewm(span=12, adjust=False).mean()
longEMA_3= list_of_data_frame_of_share_market[3]['close'].ewm(span=26, adjust=False).mean()
        
short_EMA_4= list_of_data_frame_of_share_market[4]['close'].ewm(span=9, adjust=False).mean()
signalEMA_4= list_of_data_frame_of_share_market[4]['close'].ewm(span=12, adjust=False).mean()
longEMA_4= list_of_data_frame_of_share_market[4]['close'].ewm(span=26, adjust=False).mean()
        
# shortEMA_5= list_of_data_frame_of_share_market[5]['close'].ewm(span=9, adjust=False).mean()
# signalEMA_5= list_of_data_frame_of_share_market[5]['close'].ewm(span=12, adjust=False).mean()
# longEMA_5= list_of_data_frame_of_share_market[5]['close'].ewm(span=26, adjust=False).mean()
        
# shortEMA_6= list_of_data_frame_of_share_market[6]['close'].ewm(span=9, adjust=False).mean()
# signalEMA_6= list_of_data_frame_of_share_market[6]['close'].ewm(span=12, adjust=False).mean()
# longEMA_6= list_of_data_frame_of_share_market[6]['close'].ewm(span=26, adjust=False).mean()
        
# shortEMA_7= list_of_data_frame_of_share_market[7]['close'].ewm(span=9, adjust=False).mean()
# signalEMA_7= list_of_data_frame_of_share_market[7]['close'].ewm(span=12, adjust=False).mean()
# longEMA_7= list_of_data_frame_of_share_market[7]['close'].ewm(span=26, adjust=False).mean()
        
# shortEMA_8= list_of_data_frame_of_share_market[8]['close'].ewm(span=9, adjust=False).mean()
# signalEMA_8= list_of_data_frame_of_share_market[8]['close'].ewm(span=12, adjust=False).mean()
# longEMA_8= list_of_data_frame_of_share_market[8]['close'].ewm(span=26, adjust=False).mean()
        
# shortEMA_9= list_of_data_frame_of_share_market[9]['close'].ewm(span=9, adjust=False).mean()
# signalEMA_9= list_of_data_frame_of_share_market[9]['close'].ewm(span=12, adjust=False).mean()
# longEMA_9= list_of_data_frame_of_share_market[9]['close'].ewm(span=26, adjust=False).mean()
        
        
#     list_of_EMA =[[shortEMA,signalEMA,longEMA],[shortEMA_1,signalEMA_1,longEMA_1],[shortEMA_2,signalEMA_2,longEMA_2],
#                  [shortEMA_3,signalEMA_3,longEMA_3],[short_EMA_4,signalEMA_4,longEMA_4],[shortEMA_5,signalEMA_5,longEMA_5],
#                  [shortEMA_6,signalEMA_6,longEMA_6],[shortEMA_7,signalEMA_7,longEMA_7],[shortEMA_8,signalEMA_8,longEMA_8],
#                  [shortEMA_9,signalEMA_9,longEMA_9]]
    
list_of_EMA =[[shortEMA,signalEMA,longEMA],[shortEMA_1,signalEMA_1,longEMA_1],[shortEMA_2,signalEMA_2,longEMA_2],
                 [shortEMA_3,signalEMA_3,longEMA_3],[short_EMA_4,signalEMA_4,longEMA_4]]

# %% [markdown]
# # Reference for analysis

# %% [markdown]
# list_of_EMA[0][0][0]
# list_of_EMA[0][1][0]
# list_of_EMA[0][2][0]
#
# list_of_EMA[1][0][0]
# list_of_EMA[1][1][0]
# list_of_EMA[1][2][0]

# %%
dict_of_latest_CDMA= {}
list_of_top_5_share 
for i in list_of_EMA:
    for j in i:
        for l in list_of_top_5_share:
            print(j[0])
            dict_of_latest_CDMA[l] = j[0]
            print("=======================================")
    print('...........................')
# Out:
# 58374.2
# =======================================
# 58374.2
# =======================================
# 58374.2
# =======================================
# 58374.2
# =======================================
# 58374.2
# =======================================
# 58374.2
# =======================================
# 58374.2
# =======================================
# 58374.2
# =======================================
# 58374.2
# =======================================
# 58374.2
# =======================================
# 58374.2
# =======================================
# 58374.2
# =======================================
# 58374.2
# =======================================
# 58374.2
# =======================================
# 58374.2
# =======================================
# ...........................
# 32238.2
# =======================================
# 32238.2
# =======================================
# 32238.2
# =======================================
# 32238.2
# =======================================
# 32238.2
# =======================================
# 32238.2
# =======================================
# 32238.2
# =======================================
# 32238.2
# =======================================
# 32238.2
# =======================================
# 32238.2
# =======================================
# 32238.2
# =======================================
# 32238.2
# =======================================
# 32238.2
# =======================================
# 32238.2
# =======================================
# 32238.2
# =======================================
# ...........................
# 18305.65
# =======================================
# 18305.65
# =======================================
# 18305.65
# =======================================
# 18305.65
# =======================================
# 18305.65
# =======================================
# 18305.65
# =======================================
# 18305.65
# =======================================
# 18305.65
# =======================================
# 18305.65
# =======================================
# 18305.65
# =======================================
# 18305.65
# =======================================
# 18305.65
# =======================================
# 18305.65
# =======================================
# 18305.65
# =======================================
# 18305.65
# =======================================
# ...........................
# 19782.95
# =======================================
# 19782.95
# =======================================
# 19782.95
# =======================================
# 19782.95
# =======================================
# 19782.95
# =======================================
# 19782.95
# =======================================
# 19782.95
# =======================================
# 19782.95
# =======================================
# 19782.95
# =======================================
# 19782.95
# =======================================
# 19782.95
# =======================================
# 19782.95
# =======================================
# 19782.95
# =======================================
# 19782.95
# =======================================
# 19782.95
# =======================================
# ...........................
# 19353.15
# =======================================
# 19353.15
# =======================================
# 19353.15
# =======================================
# 19353.15
# =======================================
# 19353.15
# =======================================
# 19353.15
# =======================================
# 19353.15
# =======================================
# 19353.15
# =======================================
# 19353.15
# =======================================
# 19353.15
# =======================================
# 19353.15
# =======================================
# 19353.15
# =======================================
# 19353.15
# =======================================
# 19353.15
# =======================================
# 19353.15
# =======================================
# ...........................

# %%
list_of_column_data= []
for i in list_of_EMA:
    for j in range(0,len(i)):
        list_of_column_data.append(i[0][0])
print(len(list_of_column_data))
# Out:
# 15

# %%
length_to_split = [5,5,5]

Inputt = iter(list_of_column_data)
Output = [list(islice(Inputt, elem))
          for elem in length_to_split]

# Printing Output

print("Split length list: ", length_to_split)
print("List after splitting", Output)
# Out:
# Split length list:  [5, 5, 5]
# List after splitting [[58374.2, 58374.2, 58374.2, 32238.2, 32238.2], [32238.2, 18305.65, 18305.65, 18305.65, 19782.95], [19782.95, 19782.95, 19353.15, 19353.15, 19353.15]]

# %%
numpy_array = np.array(Output)
transpose = numpy_array.T

# %%
transpose
# Out:
# array([[58374.2 , 32238.2 , 19782.95],
#        [58374.2 , 18305.65, 19782.95],
#        [58374.2 , 18305.65, 19353.15],
#        [32238.2 , 18305.65, 19353.15],
#        [32238.2 , 19782.95, 19353.15]])

# %%
data_frame =pd.DataFrame(transpose,columns=['shortEMA','signalEMA','LongEMA'])

data_frame
# Out:
#    shortEMA  signalEMA   LongEMA
# 0   58374.2   32238.20  19782.95
# 1   58374.2   18305.65  19782.95
# 2   58374.2   18305.65  19353.15
# 3   32238.2   18305.65  19353.15
# 4   32238.2   19782.95  19353.15

# %%
data_frame['Stock_name'] = list_of_top_5_share

# %% [markdown]
# # Display data in tabular format , this data autometically update from NSE Website and dislay MACD Line , Signal Line with respect to top 5 share (by Avg_price)
# and respective values

# %%
data_frame
# Out:
#    shortEMA  signalEMA   LongEMA Stock_name
# 0   58374.2   32238.20  19782.95        MRF
# 1   58374.2   18305.65  19782.95     HONAUT
# 2   58374.2   18305.65  19353.15    PAGEIND
# 3   32238.2   18305.65  19353.15   SHREECEM
# 4   32238.2   19782.95  19353.15    3MINDIA
