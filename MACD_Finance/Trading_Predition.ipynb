# %% [markdown]
# ### pynse

# %% [markdown]
# #### install pynse

# %%
pip install nsepy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from nsepy import * 
import datetime
import logging
import pandas as pd
# config logging

logging.basicConfig(level=logging.DEBUG)

# %%
from pynse import *

# %%
# init nse 

nse = Nse()
# Out:
# INFO:pynse.core:pyNse cache size: (6.07, 'MB').
# You may want to run `nse.clear_data()` if running low on disk space.

# %%
Return market status

# %%
nse.market_status()
# Out:
# INFO:pynse.core:downloading market status
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.nseindia.com:443
# DEBUG:urllib3.connectionpool:https://www.nseindia.com:443 "GET / HTTP/1.1" 200 40892
# DEBUG:urllib3.connectionpool:https://www.nseindia.com:443 "GET /api/marketStatus HTTP/1.1" 200 222
# {'marketState': [{'market': 'Capital Market',
#    'marketStatus': 'Close',
#    'tradeDate': '06-Sep-2021',
#    'index': 'NIFTY 50',
#    'last': 17323.6,
#    'variation': 89.44999999999709,
#    'percentChange': 0.52,
#    'marketStatusMessage': 'Market is Closed'},
#   {'market': 'Currency',
#    'marketStatus': 'Close',
#    'tradeDate': '06-Sep-2021',
#    'index': '',
#    'last': '',
#    'variation': '',
#    'percentChange': '',
#    'marketStatusMessage': 'Market is Closed'},
#   {'market': 'Commodity',
#    'marketStatus': 'Close',
#    'tradeDate': '06-Sep-2021',
#    'index': '',
#    'last': '',
#    'variation': '',
#    'percentChange': '',
# ...

# %%
nse.info('SBIN')
# Out:
# INFO:pynse.core:downloading symbol info for SBIN
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.nseindia.com:443
# DEBUG:urllib3.connectionpool:https://www.nseindia.com:443 "GET / HTTP/1.1" 200 40897
# DEBUG:urllib3.connectionpool:https://www.nseindia.com:443 "GET /api/equity-meta-info?symbol=SBIN HTTP/1.1" 200 209
# {'symbol': 'SBIN',
#  'companyName': 'State Bank of India',
#  'industry': 'BANKS',
#  'activeSeries': ['EQ'],
#  'debtSeries': [],
#  'tempSuspendedSeries': ['IL', 'N1', 'N2', 'N3', 'N4', 'N5', 'N6'],
#  'isFNOSec': True,
#  'isCASec': False,
#  'isSLBSec': True,
#  'isDebtSec': False,
#  'isSuspended': False,
#  'isETFSec': False,
#  'isDelisted': False,
#  'isin': 'INE062A08066'}

# %% [markdown]
# # Bhavcopy

# %%
daily_share_price =nse.bhavcopy()
daily_share_price
# Out:
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.nseindia.com:443
# DEBUG:urllib3.connectionpool:https://www.nseindia.com:443 "GET / HTTP/1.1" 200 40900
# DEBUG:urllib3.connectionpool:https://www.nseindia.com:443 "GET /api/historical/cm/equity?symbol=SBIN&series=%5B%22EQ%22%5D&from=27-08-2021&to=05-09-2021&csv=true HTTP/1.1" 200 437
# DEBUG:pynse.core:read C:\Users\kumar\.pynse/bhavcopy_eq/bhav_2021-09-03.pkl from disk
#                         DATE1  PREV_CLOSE  OPEN_PRICE  HIGH_PRICE  LOW_PRICE  \
# SYMBOL     SERIES
# 20MICRONS  EQ      2021-09-03       53.85       54.45       54.85      53.15
# 21STCENMGM EQ      2021-09-03       34.85       35.50       35.50      35.50
# 3MINDIA    EQ      2021-09-03    24543.05    24900.00    25000.00   24400.00
# 5PAISA     EQ      2021-09-03      466.15      463.00      475.10     463.00
# 63MOONS    EQ      2021-09-03       94.80       93.75       99.45      93.75
# ...

# %%
list_of_top_10_share= []
daily_share_price =nse.bhavcopy()
filt = daily_share_price['AVG_PRICE'].sort_values(ascending= False).head(10)
# daily_share_price[filt]
t= filt
t
# Out:
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.nseindia.com:443
# DEBUG:urllib3.connectionpool:https://www.nseindia.com:443 "GET / HTTP/1.1" 200 40893
# DEBUG:urllib3.connectionpool:https://www.nseindia.com:443 "GET /api/historical/cm/equity?symbol=SBIN&series=%5B%22EQ%22%5D&from=27-08-2021&to=05-09-2021&csv=true HTTP/1.1" 200 437
# DEBUG:pynse.core:read C:\Users\kumar\.pynse/bhavcopy_eq/bhav_2021-09-03.pkl from disk
# SYMBOL      SERIES
# MRF         EQ        82217.08
# HONAUT      EQ        40445.65
# PAGEIND     EQ        32493.84
# SHREECEM    EQ        30275.16
# 3MINDIA     EQ        24799.79
# NIFTYEES    EQ        22334.57
# NESTLEIND   EQ        20230.60
# ABBOTINDIA  EQ        19958.16
# TASTYBITE   EQ        18805.47
# BAJAJFINSV  EQ        16681.70
# Name: AVG_PRICE, dtype: float64

# %%
t.index
# Out:
# MultiIndex([(       'MRF', 'EQ'),
#             (    'HONAUT', 'EQ'),
#             (   'PAGEIND', 'EQ'),
#             (  'SHREECEM', 'EQ'),
#             (   '3MINDIA', 'EQ'),
#             (  'NIFTYEES', 'EQ'),
#             ( 'NESTLEIND', 'EQ'),
#             ('ABBOTINDIA', 'EQ'),
#             ( 'TASTYBITE', 'EQ'),
#             ('BAJAJFINSV', 'EQ')],
#            names=['SYMBOL', 'SERIES'])

# %%
t.reset_index(inplace= True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-20-8c658f40dab2> in <module>
# ----> 1 t.reset_index(inplace= True)
#
# ~\Anaconda3\lib\site-packages\pandas\core\series.py in reset_index(self, level, drop, name, inplace)
#    1271                 ).__finalize__(self, method="reset_index")
#    1272         elif inplace:
# -> 1273             raise TypeError(
#    1274                 "Cannot reset_index inplace on a Series to create a DataFrame"
#    1275             )
#
# TypeError: Cannot reset_index inplace on a Series to create a DataFrame

# %%
list_of_top_10_share_company= []

list_of_top_10_share_company = t['SYMBOL']

for i in list_of_top_10_share_company:
    print(i)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'SYMBOL'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-23-5a9b04054f52> in <module>
# ...

# %%
daily_share_price =nse.bhavcopy(datetime.date(2020,4,5))
daily_share_priceprice
# Out:
# DEBUG:pynse.core:read C:\Users\kumar\.pynse/bhavcopy_eq/bhav_2020-04-05.pkl from disk
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-ebec9773fcdb> in <module>
#       1 daily_share_price =nse.bhavcopy(datetime.date(2020,4,5))
# ----> 2 daily_share_priceprice
#
# NameError: name 'daily_share_priceprice' is not defined

# %%
nse.bhavcopy_fno()
# Out:
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.nseindia.com:443
# DEBUG:urllib3.connectionpool:https://www.nseindia.com:443 "GET / HTTP/1.1" 200 40956
# DEBUG:urllib3.connectionpool:https://www.nseindia.com:443 "GET /api/historical/cm/equity?symbol=SBIN&series=%5B%22EQ%22%5D&from=27-08-2021&to=05-09-2021&csv=true HTTP/1.1" 200 437
# DEBUG:pynse.core:downloading bhavcopy for 2021-09-03
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.nseindia.com:443
# DEBUG:urllib3.connectionpool:https://www.nseindia.com:443 "GET / HTTP/1.1" 200 40957
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): archives.nseindia.com:443
# DEBUG:urllib3.connectionpool:https://archives.nseindia.com:443 "GET /content/historical/DERIVATIVES/2021/SEP/fo03SEP2021bhav.csv.zip HTTP/1.1" 200 665612
# INFO:numexpr.utils:Note: NumExpr detected 16 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 8.
# ...

# %%
nse.bhavcopy_fno(datetime.date(2021,9,3))
# Out:
# DEBUG:pynse.core:read C:\Users\kumar\.pynse/bhavcopy_fno/bhav_2021-09-03.pkl from disk
#           INSTRUMENT  EXPIRY_DT  STRIKE_PR OPTION_TYP      OPEN      HIGH  \
# SYMBOL
# BANKNIFTY     FUTIDX 2021-09-30        0.0         XX  37038.95  37249.00
# BANKNIFTY     FUTIDX 2021-10-28        0.0         XX  37150.50  37364.90
# BANKNIFTY     FUTIDX 2021-11-25        0.0         XX  37300.00  37494.95
# FINNIFTY      FUTIDX 2021-09-09        0.0         XX      0.00      0.00
# FINNIFTY      FUTIDX 2021-09-16        0.0         XX      0.00      0.00
# ...              ...        ...        ...        ...       ...       ...
# ZEEL          OPTSTK 2021-11-25      250.0         PE      0.00      0.00
# ZEEL          OPTSTK 2021-11-25      255.0         PE      0.00      0.00
# ZEEL          OPTSTK 2021-11-25      260.0         PE      0.00      0.00
# ZEEL          OPTSTK 2021-11-25      265.0         PE      0.00      0.00
# ...

# %% [markdown]
# # Download historical data

# %%
nse.get_hist('INFY')
# Out:
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.nseindia.com:443
# DEBUG:urllib3.connectionpool:https://www.nseindia.com:443 "GET / HTTP/1.1" 200 40957
# DEBUG:urllib3.connectionpool:https://www.nseindia.com:443 "GET /api/historical/cm/equity?symbol=INFY&series=%5B%22EQ%22%5D&from=06-08-2021&to=05-09-2021&csv=true HTTP/1.1" 200 1088
#                open     high      low    close    volume
# Date
# 2021-08-06  1657.00  1660.65  1644.00  1650.20   3754855
# 2021-08-09  1661.00  1667.45  1646.40  1663.30   5018477
# 2021-08-10  1668.00  1680.00  1661.05  1677.25   6846517
# 2021-08-11  1674.80  1684.00  1668.00  1677.55   4899639
# 2021-08-12  1679.15  1696.50  1674.00  1689.60   5659579
# 2021-08-13  1697.00  1722.50  1691.30  1712.20   5612790
# 2021-08-16  1707.70  1719.95  1690.10  1704.40   4564109
# 2021-08-17  1703.90  1748.90  1686.55  1741.65   9510390
# 2021-08-18  1729.00  1755.50  1727.00  1733.45   6686090
# ...

# %%
nse.get_hist('INFY', datetime.date(2010,1,1),datetime.date(2021,9,3))
# Out:
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.nseindia.com:443
# DEBUG:urllib3.connectionpool:https://www.nseindia.com:443 "GET / HTTP/1.1" 200 40960
# DEBUG:urllib3.connectionpool:https://www.nseindia.com:443 "GET /api/historical/cm/equity?symbol=INFY&series=%5B%22EQ%22%5D&from=01-01-2010&to=26-04-2011&csv=true HTTP/1.1" 200 13111
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.nseindia.com:443
# DEBUG:urllib3.connectionpool:https://www.nseindia.com:443 "GET / HTTP/1.1" 200 40959
# DEBUG:urllib3.connectionpool:https://www.nseindia.com:443 "GET /api/historical/cm/equity?symbol=INFY&series=%5B%22EQ%22%5D&from=27-04-2011&to=19-08-2012&csv=true HTTP/1.1" 200 14210
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.nseindia.com:443
# DEBUG:urllib3.connectionpool:https://www.nseindia.com:443 "GET / HTTP/1.1" 200 40954
# ...

# %%
hdfc= nse.get_hist('HDFC', datetime.date(2010,1,1),datetime.date(2021,9,3))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-82f9c7771eb0> in <module>
# ----> 1 hdfc= nse.get_hist('HDFC', datetime.date(2010,1,1),datetime.date(2021,9,3))
#
# NameError: name 'nse' is not defined
